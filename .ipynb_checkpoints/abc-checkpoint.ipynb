# %% [markdown]
# # Programowanie
#
# Do zajęć potrzebujemy ściągnąć plik z [tego adresu](https://wolnelektury.pl/media/book/txt/pan-tadeusz.txt) i zapisać go w tym samym katalogu co skrypt pythonowy.
#
# ## Zadanie 1
#
# Napisz program który odczyta tekst z pliku tekstowego o podanej ścieżce.
#
# ### Podpowiedź
#
# Do odczytywania plików tekstowych użyj funkcji `open('pan_tadeusz.txt').read()`.
#
# ## Zadanie 2
#
# Wykorzystując moduł `sys` napisz program który pozwoli na odczytywanie dowolnego pliku tekstowego poprzez podanie jego nazwy jako argument.
#
# Przykład:
#
# ```
# python main.py pan_tadeusz.txt
# ```
#
# Powinien otworzyć plik o nazwie `pan_tadeusz.txt`.
#
# ## Zadanie 3
#
# Napisz program który odczyta tekst z podanego pliku tekstowego i zwróci informację ile jest w nim liter `a`.
#
# ## Zadanie 4
#
# Napisz zmodyfikowaną wersję powyższego programu który wyszuka dowolną literę (podaną jako argument na wejściu programu) i powie ile razy się powtarza.
#
# ## Zadanie 5
#
# Napisz program który zwróci informację ile linii tekstu znajduje się w dokumencie.
#
# Podpowiedź: zamiast `.read()` skorzystaj z metody `.readlines()`.
#
# ## Zadanie 6
#
# Napisz program który policzy średnią długość każdej linii w podanym pliku tekstowym.
#
# ## Zadanie 7
#
# Napisz progam który policzy wszystkie słowa w podanym pliku tekstowym.
#
# Podpowiedź: skorzystaj z metody `.split()`. Np:
#
# ```python
# "ala ma kota".split()
# ```
#
# zwróci:
#
# ```
# ["ala", "ma", "kota"]
# ```
#
# ## Zadanie 8
#
# Policz ile razy w tekście pojawia się konkretne słowo (dane na wejściu).
#
# ## Zadanie 9
#
# Korzystając ze struktury słownika znajdź słowo które powtarza się najczęściej. Przedstaw procentowy rozkład wszystkich słów.
#
#
# ## Zadanie 10
#
# Stwórz program który wczytuje z pliku tekstowego listę liczb i wypisuje na ekran ich kwadraty.
#
# ## Zadanie 11
#
# Stwórz program który wczytuje z pliku tekstowego listę liczb i znajduje największą i najmniejszą z nich.
#
# ## Zadanie 12
#
# Stwórz program który wczytuje z pliku tekstowego listę liczb i wypisuje je w uporządkowanym szyku.
#
# ## Zadanie 13
#
# Stwórz program który wczytuje z pliku tekstowego listę liczb i wypisuje na ekran ich sumę.
